# %% [markdown]
# <a href="https://colab.research.google.com/github/elshaymaAnalyst/PythonProject/blob/main/Linear_Regression_Train_test__carprice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/carprices-1 (1).csv')

# %%
df.head(2)
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000

# %%
df.columns
# Out:
# Index(['Mileage', 'Age(yrs)', 'Sell Price($)'], dtype='object')

# %%
x=df[['Mileage', 'Age(yrs)']]

# %%
y=df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %%
#splitting the data 80% train data ,20% Test Data
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.80,random_state=42)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 8     91000         8
# 5     59000         5
# 11    79000         7
# 3     22500         2
# 18    87600         8
# 16    28000         2
# 13    58780         4
# 2     57000         5
# 9     67000         6
# 19    52000         5
# 4     46000         4
# 12    59000         5
# 7     72000         6
# 10    83000         7
# 14    82450         7
# 6     52000         5

# %%
from sklearn.linear_model import LinearRegression

# %%
lrm=LinearRegression()

# %%
lrm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lrm.predict(x_test)

# %%
pd.DataFrame({'y_test':y_test,'y_test':y_pred})
# Out:
#          y_test
# 0  22262.481892
# 1  22571.643802
# 2  38560.990557
# 3  35176.545140

# %%
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 10120000.553731432

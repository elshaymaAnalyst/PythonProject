# %% [markdown]
# <a href="https://colab.research.google.com/github/elshaymaAnalyst/PythonProject/blob/main/Linear_Regreesion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/homeprices (1) (1) (1).csv')

# %%
df.head(5)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    5 non-null      int64
#  1   price   5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %%
#EDA

# %%
df[['area','price']].corr()
# area is 97% corelated with price
# Out:
#            area     price
# area   1.000000  0.978994
# price  0.978994  1.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['area'],df['price'],marker='*',color='red')
plt.xlabel('area')
plt.ylabel('price')
plt.title('area vs price')
# Out:
# Text(0.5, 1.0, 'area vs price')

# %%
x=df[['area']]

# %%
y=df['price']

# %%
from sklearn.linear_model import LinearRegression

# %%
lrm=LinearRegression()

# %%
lrm.fit(x,y)
# Out:
# LinearRegression()

# %%
lrm.predict([[3300]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
lrm.coef_
#m=135.78
# Out:
# array([135.78767123])

# %%
lrm.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
#y=mx+b
#=135.78(3300)+180616.43
 #=628715.75

# %%
lrm.fit(df[['area']],df['price'])

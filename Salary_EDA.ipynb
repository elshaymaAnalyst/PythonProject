# %% [markdown]
# <a href="https://colab.research.google.com/github/elshaymaAnalyst/PythonProject/blob/main/Salary_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Salary (1).csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0  age  salary city  experience
# 0           0   20   54777   NY          24
# 1           1   23   43824   NY          33

# %%
import plotly.express as px

# %%
px.histogram(df, x='age')
#we have more employees in 20 to 24 &55 to 59
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'salary', 'city', 'experience'], dtype='object')

# %%
px.histogram(df, x='experience')
#we have more employess is 5 to 9&20 to 24
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['city'].value_counts().plot.bar()
#more employees are in LA
# Out:
# <Axes: xlabel='city'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'salary', 'city', 'experience'], dtype='object')

# %%
df[['age','salary']].corr()
#There is no relationship between age and salary.it is 2%
# Out:
#              age    salary
# age     1.000000  0.026072
# salary  0.026072  1.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['age'],df['salary'],color = 'red',marker='*')
plt.xlabel('age')
plt.ylabel('salary')
plt.title('age vs salary')
plt.show()

# %%
df.columns
#experience & salary
# Out:
# Index(['Unnamed: 0', 'age', 'salary', 'city', 'experience'], dtype='object')

# %%
df[['experience','salary']].corr()
#There is no relationship between experience and salary.it is 11%
# Out:
#             experience    salary
# experience    1.000000 -0.112658
# salary       -0.112658  1.000000

# %%
plt.scatter(df['experience'],df['salary'],color = 'red',marker='*')
plt.xlabel('experience')
plt.ylabel('salary')
plt.title('experience vs salary')
plt.show()

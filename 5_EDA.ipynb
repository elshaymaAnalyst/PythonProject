# %% [markdown]
# <a href="https://colab.research.google.com/github/elshaymaAnalyst/PythonProject/blob/main/5_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/Timeseries_correct.xlsx')

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    9775  CA-2014-169019 2014-07-26 2014-07-30  Standard Class    LF-17185
# 1    4992  US-2017-122714 2017-12-07 2017-12-13  Standard Class    HG-14965
#
#    Customer Name    Segment        Country         City  ...   Region  \
# 0    Luke Foster   Consumer  United States  San Antonio  ...  Central
# 1  Henry Goldwyn  Corporate  United States      Chicago  ...  Central
#
#         Product ID         Category Sub-Category  \
# 0  OFF-BI-10004995  Office Supplies      Binders
# 1  OFF-BI-10001120  Office Supplies      Binders
#
#                                 Product Name     Sales Quantity  Discount  \
# 0  GBC DocuBind P400 Electric Binding System  2177.584        8       0.8
# 1       Ibico EPK-21 Electric Binding System  1889.990        5       0.8
#
#       Profit  Shipping Cost
# 0 -3701.8928              5
# 1 -2929.4845              5
#
# [2 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost'],
#       dtype='object')

# %%
#EDA

# %%
# Univariate

# %%
import plotly.express as px

# %%
px.histogram(df,x='Quantity')
# Majority of Quantity shipped in 2 & 3
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns

# %%
sns.histplot(df,x='Quantity')
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Quantity'])
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.title('Histogram of Quantity')
plt.show()

# %%
#Universial Analysis for object columns

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0    9775  CA-2014-169019 2014-07-26 2014-07-30  Standard Class    LF-17185
# 1    4992  US-2017-122714 2017-12-07 2017-12-13  Standard Class    HG-14965
#
#    Customer Name    Segment        Country         City  ...   Region  \
# 0    Luke Foster   Consumer  United States  San Antonio  ...  Central
# 1  Henry Goldwyn  Corporate  United States      Chicago  ...  Central
#
#         Product ID         Category Sub-Category  \
# 0  OFF-BI-10004995  Office Supplies      Binders
# 1  OFF-BI-10001120  Office Supplies      Binders
#
#                                 Product Name     Sales Quantity  Discount  \
# 0  GBC DocuBind P400 Electric Binding System  2177.584        8       0.8
# 1       Ibico EPK-21 Electric Binding System  1889.990        5       0.8
#
#       Profit  Shipping Cost
# 0 -3701.8928              5
# 1 -2929.4845              5
#
# [2 rows x 22 columns]

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Order ID', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment',
#        'Country', 'City', 'State', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Ship Mode'].value_counts().plot.bar()
plt.xlabel('Ship Mode')
plt.ylabel('Frequency')
plt.title('Ship Mode and customer count');
plt.show()
#Majority of customer are in standerd class

# %%
df['Segment'].value_counts().plot.bar()
plt.xlabel('Segment')
plt.ylabel('Frequency')
plt.title('Segment and customer count');
plt.show()
#Majority of the customers are consumer

# %%
df['Ship Mode'].value_counts().plot.bar()
plt.xlabel('Ship Mode')
plt.ylabel('Frequency')
plt.title('Ship Mode and customer count');
plt.show()
#Majority of customer are in Standerd class

# %%
df['Region'].value_counts().plot.bar()
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.title('Region and customer count');
plt.show()
#Majority of customer are in West Region

# %%
df['Category'].value_counts().plot.bar()
plt.xlabel('Category')
plt.ylabel('Category')
plt.title('Categoryn and customer count');
plt.show()
#Majority of customer are in office supplies

# %%
#BI Variate

# %%
#TWO Numberical values

# %%
px.scatter(df,x='Sales',y='Profit')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[['Sales','Profit']].corr()
#Sales is 47% Correlated with profit
#There is no high correlation
# Out:
#            Sales    Profit
# Sales   1.000000  0.479064
# Profit  0.479064  1.000000

# %%
sns.heatmap(df[['Sales','Profit']].corr(),annot=True)
#
# Out:
# <Axes: >

# %%
plt.scatter(df['Sales'],df['Profit'],marker='*',color='red')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Relationship between Sales & Profit')
plt.show()
